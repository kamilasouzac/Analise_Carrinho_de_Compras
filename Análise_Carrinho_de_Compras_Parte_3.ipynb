# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilasouzac/Analise_Carrinho_de_Compras/blob/main/An%C3%A1lise_Carrinho_de_Compras_Parte_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RECAPITULANDO**

# %% [markdown]
# Estamos trabalhando com o dataset originalmente disponível no Kaggle para fazermos um estudo da cesta do carrinho de compras.
#
# O dataset original pode ser oncnetrado em: https://www.kaggle.com/datasets/mittalvasu95/the-bread-basket
#
# Ao final do projeto, queremos responder todas as seguintes perguntas:
#
# 1. Quais são os itens mais vendidos?
# 2. Quais items podem ser removidos do cardápio para dar espaço para novos pratos?
# 3. Qual período do dia a padaria mais vende?
# 4. O movimento no final de semana é maior do que durante a semana?
# 5. Existe alguma sazonalidade nas vendas?
# 6. Quais são os itens mais vendidos em conjunto?
# 7. Quais combos a padaria pode criar para estimular as vendas?
#
# Na parte 1 (o notebook pode ser encontrado nesse mesmo repositório), tratamos nosso dataset, traduzindo os valores para facilitar o acesso do público brasileiro, verificamos se existiam dados nulos e transformamos o dtypes para melhor uso durante as análises.
#
# Respondemos ainda as três primeiras perguntas, e preparamos nossa apresentação inicial para nosso cliente (o deck de slides também está disponível nesse repositório).
#
# Na parte 2 responsemos as perguntas 4 e 5 e preparamos a apresentação dos resultados (todos os materiais podem ser concontrados nesse diretório).
#
# Agora, vamos finalizar nosso estudo, respondendo as perguntas 6 e 7.

# %% [markdown]
# #**PREPANDANDO O AMBIENTE**

# %% [markdown]
# ###Bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# Na versão do pandas utilizada, eu estava recebendo a mensagem de erro abaixo:

# %% [markdown]
#  > /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# O código abaixo foi a sulução para resolvermos o erro.

# %%
pip install --upgrade ipykernel
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (5.5.6)
# Collecting ipykernel
#   Downloading ipykernel-6.25.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.2/154.2 kB 1.6 MB/s eta 0:00:00
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (1.6.6)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel) (1.5.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.2.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Installing collected packages: jedi, comm, ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.25.2 which is incompatible.
# Successfully installed comm-0.1.4 ipykernel-6.25.2 jedi-0.19.1

# %%
print('Versão do Pandas utilizada:', pd.__version__)
print('Versão do Seaborn utilizada:', sns.__version__)
# Out:
# Versão do Pandas utilizada: 1.5.3
# Versão do Seaborn utilizada: 0.12.2
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ###Parâmetros dos gráficos

# %%
plt.rcParams['figure.figsize'] = (12, 6) #Tamanho do gráfico
sns.set_theme(style = 'whitegrid', palette = 'plasma')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #**IMPORTANDO O DATASET**

# %% [markdown]
# Vamos usar o DF já tratado na parte 1.

# %%
df = pd.read_csv('df_tratado.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Transação              Item Período_do_Dia Período_da_Semana  \
# 0          1               Pão          Manhã   Final_de_Semana
# 1          2       Escandinavo          Manhã   Final_de_Semana
# 2          2       Escandinavo          Manhã   Final_de_Semana
# 3          3  Chocolate quente          Manhã   Final_de_Semana
# 4          3            Geléia          Manhã   Final_de_Semana
#
#           Carimbo_data        Data      Dia      Mês   Ano  Hora Hora_Completa
# 0  2016-10-30 09:58:00  2016-10-30  Domingo  Outubro  2016     9         09:58
# 1  2016-10-30 10:05:00  2016-10-30  Domingo  Outubro  2016    10         10:05
# 2  2016-10-30 10:05:00  2016-10-30  Domingo  Outubro  2016    10         10:05
# 3  2016-10-30 10:07:00  2016-10-30  Domingo  Outubro  2016    10         10:07
# 4  2016-10-30 10:07:00  2016-10-30  Domingo  Outubro  2016    10         10:07

# %%
df['Carimbo_data'] = pd.to_datetime(df['Carimbo_data'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['Data'] = pd.to_datetime(df['Data'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **6. Quais são os itens mais vendidos em conjunto?**

# %% [markdown]
# ###**Regras de Associação**

# %% [markdown]
# Para responder nossas duas últimas perguntas, vamos usar uma Regra de Associação - um modelo de ML que nos ajuda a explorar as relações entre os itens da nossa amostra [1](https://medium.com/@bernardo.costa/uma-introdu%C3%A7%C3%A3o-ao-algoritmo-apriori-60b11293aa5a),[2](https://https://en.wikipedia.org/wiki/Association_rule_learning).

# %% [markdown]
# Aqui vamos usar o algoritimo Apriori. O moodelo trás quatro métricas importantes para a análise: suporte, lift, confiança e convicçaõ. Aqui uma definição super didática do [Vinicius dos Santos](https://www.computersciencemaster.com.br/como-funciona-o-algoritmo-apriori/):

# %% [markdown]
# > **SUPORTE**: "Este número é a popularidade do item no conjunto de dados estudado (dataset). Sendo assim esse número é definido pela quantidade de vezes que o item apareceu em uma transação, dividido pela quantidade de transações existentes no dataset". O suporte é calculado da seguinte maneira: supp(x) = (numero de transações que X aparece) / (numero total de transações)

# %% [markdown]
# > **CONFIANÇA:** "Se X for comprado, qual a chance de Y ser comprado?"
#
# >"A confiança é um número que expressa a possibilidade de um item ser comprado quando outro item correlato é comprado. Por exemplo, qual a confiança que um cliente irá comprar um hambúrguer considerando que ele já comprou cebolas e batatas.
#
# >A confiança é calculada através da seguinte equação: conf(X→Y) = supp(X U Y) / supp(X)"

# %% [markdown]
# > **LIFT:** "Esta medida calcula também a possibilidade de um item ser comprado em relação a outro item. Porém, esta medida considera a popularidade de ambos os itens.
#
# > lift(X→Y) = supp(X U Y) / supp(X) * supp(Y)
#
# > Neste cálculo podemos analisar da seguinte forma: se o valor de lift(x→y) > 1 existe uma relação de compra entre estes dois itens. Já se o valor de lift(x→y) < 1 é muito provável que não exista uma relação clara expressa no dataset."

# %% [markdown]
# >**CONVICÇÃO:** "conv (x → y) = 1 – supp(y) / 1 – conf(x → y)
#
# >Pode ser interpretado como a razão da frequência esperada que X ocorre sem Y (isto é, a frequência que a regra faz uma predição incorreta) se X e Y fossem independentes divididos pela frequência observada de predições incorretas."

# %% [markdown]
# Com as definições em mãos, vamos ao modelo. Primeiro, ajustaremos os dados com o *TransactionEncoder* e logo em seguida passaremos esse novo DF para o algoritimo.

# %%
#Obtendo um "lista de listas" com os itens de cada transação

carrinhos = df.groupby('Transação')['Item'].apply(list).to_list()
carrinhos
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Pão'],
#  ['Escandinavo', 'Escandinavo'],
#  ['Chocolate quente', 'Geléia', 'Biscoitos'],
#  ['Muffin'],
#  ['Café', 'Massa folhada', 'Pão'],
#  ['Medialuna', 'Massa folhada', 'Muffin'],
#  ['Medialuna', 'Massa folhada', 'Café', 'Chá'],
#  ['Massa folhada', 'Pão'],
#  ['Pão', 'Muffin'],
#  ['Escandinavo', 'Medialuna'],
#  ['Pão', 'Medialuna', 'Pão'],
#  ['Geléia', 'Café', 'Hambúrguer no prato', 'Massa folhada', 'Chá'],
#  ['Cesto', 'Pão', 'Café'],
#  ['Pão', 'Medialuna', 'Massa folhada'],
#  ['Água mineral', 'Escandinavo'],
#  ['Pão', 'Medialuna', 'Café'],
#  ['Chocolate quente'],
#  ['Farm House'],
#  ['Farm House', 'Pão'],
#  ['Pão', 'Medialuna'],
#  ['Café', 'Café', 'Medialuna', 'Pão'],
#  ['Geléia'],
#  ['Escandinavo', 'Muffin'],
#  ['Pão'],
#  ['Escandinavo'],
#  ['Fudge'],
#  ['Escandinavo'],
#  ['Café', 'Pão'],
#  ['Pão', 'Geléia'],
#  ['Pão'],
#  ['Cesto'],
#  ['Escandinavo', 'Muffin'],
#  ['Café'],
#  ['Café', 'Muffin'],
#  ['Muffin', 'Escandinavo'],
#  ['Chá', 'Pão'],
#  ['Café', 'Pão'],
#  ['Pão', 'Chá'],
#  ['Escandinavo'],
#  ['Suco', 'Hambúrguer no prato', 'Café', 'Muffin'],
#  ['Escandinavo'],
#  ['Pão', 'Chá'],
#  ['Escandinavo', 'Fudge'],
#  ['Café', 'Medialuna'],
#  ['Café', 'Chocolate quente', 'Medialuna'],
#  ['Café'],
#  ["Ella's Kitchen Pouches", 'Suco', 'Pão', 'Muffin', 'Geléia'],
#  ['Café'],
#  ['Café', 'Café', 'Medialuna'],
#  ['Pão', 'Bolo esponja vitoriano'],
#  ['Pão'],
#  ['Escandinavo'],
#  ['Pão'],
#  ['Frittata', 'Café', 'Chá', 'Hearty & Seasonal'],
#  ['Café', 'Frittata'],
#  ['Escandinavo'],
#  ['Bolo esponja vitoriano', 'Chocolate quente', 'Chá', 'Sopa'],
#  ['Chá'],
#  ['Biscoitos', 'Café', 'Suco', 'Café'],
#  ['Café'],
#  ['Tigelas variadas',
#   'Hearty & Seasonal',
#   'Hearty & Seasonal',
#   'Café',
#   'Smoothies',
#   'Café'],
#  ['Café'],
#  ['Bolo'],
#  ['Hambúrguer no prato', 'Whey Protein', 'Chá', 'Café'],
#  ['Hearty & Seasonal', 'Frittata', 'Água mineral'],
#  ['Hearty & Seasonal', 'Água mineral', 'Muffin'],
#  ['Frittata', 'Café', 'Chá', 'Escandinavo', 'Sanduíche de frango'],
#  ['Pão', 'Chá', 'Bolo esponja vitoriano'],
#  ['Fudge'],
#  ['Muffin'],
#  ['Café', 'Pão'],
#  ['Pão'],
#  ['Café', 'Pão'],
#  ['Geléia', 'Frittata'],
#  ['Café'],
#  ['Escandinavo'],
#  ['Fudge'],
#  ['Fudge', 'Chá', 'Café', 'Muffin'],
#  ['Frittata', 'Pão', 'Café'],
#  ['Café', 'Bolo'],
#  ['Hambúrguer no prato', 'Pão'],
#  ['Café', 'Pão'],
#  ['Pão'],
#  ['Café', 'Café', 'Massa folhada', 'Medialuna'],
#  ['Suco'],
#  ['Pão'],
#  ['Café', 'Café', 'Geléia'],
#  ['Pão'],
#  ['Pão', 'Café'],
#  ['Chá'],
#  ['Café'],
#  ['Pão', 'Coca-Cola'],
#  ['Café', 'Café'],
#  ['Chá', 'Massa folhada', 'Farm House'],
#  ['Massa folhada', 'Massa folhada', 'Café', 'Suco'],
#  ['Café', 'Massa folhada', 'Suco'],
#  ['Farm House'],
#  ['Massa folhada', 'Massa folhada', 'Café', 'Pão'],
#  ['Pão'],
#  ['Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Pão'],
#  ['Café', 'Café', 'Medialuna', 'Muffin', 'Café'],
#  ['Café', 'Chá', 'Bolo'],
#  ['Café', 'Café', 'Massa folhada', 'Massa folhada'],
#  ['Café', 'Chá'],
#  ['Farm House', 'Muffin'],
#  ['Pão', 'Muffin', 'Massa folhada'],
#  ['Massa folhada'],
#  ['Café'],
#  ['Café'],
#  ['Café', 'Bolo'],
#  ['Farm House'],
#  ['Pão'],
#  ['Café'],
#  ['Biscoitos', 'Bolo', 'Café', 'Suco de frutas'],
#  ['Biscoitos', 'Biscoitos', 'Chá', 'Massa folhada'],
#  ['Café', 'Café', 'Muffin'],
#  ['Farm House'],
#  ['Café', 'Pão'],
#  ['Biscoitos'],
#  ['Geléia', 'Café', 'Café', 'Suco'],
#  ['Café', 'Sopa'],
#  ['Chá'],
#  ['Café', 'Geléia'],
#  ['Farm House'],
#  ['Hambúrguer no prato', 'Café', 'Chá'],
#  ['Café', 'Café', 'Bolo'],
#  ['Café', 'Café', 'Muffin'],
#  ['Pão', 'Café'],
#  ['Chá', 'Suco', 'Tigelas variadas', 'Biscoitos'],
#  ['Hearty & Seasonal', 'Sopa'],
#  ['Hearty & Seasonal', 'Chá', 'Farm House'],
#  ['Pão'],
#  ['Chá', 'Sopa'],
#  ['Farm House'],
#  ['Sopa', 'Hearty & Seasonal', 'Café'],
#  ['Pão', 'Muffin', 'Hearty & Seasonal'],
#  ['Café', 'Café', 'Biscoitos'],
#  ['Pão'],
#  ['Chá', 'Muffin'],
#  ['Chá'],
#  ['Sopa', 'Hearty & Seasonal'],
#  ['Café', 'Chá', 'Focaccia'],
#  ['Sanduíche'],
#  ['Hambúrguer no prato', 'Café'],
#  ['Fudge', 'Café', 'Café'],
#  ['Café'],
#  ['Pão'],
#  ['Coca-Cola', 'Sopa'],
#  ['Muffin'],
#  ['Chá', 'Café', 'Biscoitos', 'Muffin'],
#  ['Whey Protein', 'Hearty & Seasonal', 'Café', 'Coca-Cola'],
#  ['Chá', 'Muffin', 'Sanduíche'],
#  ['Café', 'Muffin'],
#  ['Café', 'Pão'],
#  ['Café', 'Muffin'],
#  ['Pão', 'Chocolate quente', 'Biscoitos'],
#  ['Água mineral', 'Muffin'],
#  ['Chá'],
#  ['Muffin'],
#  ['Café', 'Suco'],
#  ['Café', 'Muffin'],
#  ['Chá'],
#  ['Café', 'Muffin'],
#  ['Sanduíche', 'Hearty & Seasonal', 'Pão', 'Água mineral'],
#  ['Chá', 'Café'],
#  ['Água mineral'],
#  ['Café'],
#  ['Sopa', 'Chá'],
#  ['Pão', 'Café'],
#  ['Pão', 'Muffin'],
#  ['Café'],
#  ['Pão'],
#  ['Biscoitos', 'Café'],
#  ['Café', 'Massa folhada'],
#  ['Café', 'Massa folhada'],
#  ['Geléia', 'Chá'],
#  ['Chá', 'Chá'],
#  ['Massa folhada', 'Massa folhada', "Ella's Kitchen Pouches"],
#  ['Massa folhada'],
#  ['Farm House', 'Chá'],
#  ['Chá', 'Bolo esponja vitoriano'],
#  ['Chá', 'Massa folhada'],
#  ['Pão'],
#  ['Café'],
#  ['Pão', 'Café'],
#  ['Café', 'Massa folhada', 'Massa folhada'],
#  ['Sopa', 'Chá'],
#  ['Pão'],
#  ['Café'],
#  ['Pão', 'Pão'],
#  ['Pão', 'Escandinavo'],
#  ['Pão', 'Bolo', 'Biscoitos'],
#  ['Café', 'Café', 'Chá'],
#  ['Café', 'Biscoitos'],
#  ['Café'],
#  ['Pão'],
#  ['Café', 'Massa folhada'],
#  ['Café', 'Café'],
#  ['Café'],
#  ['Escandinavo', 'Pão'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Escandinavo', 'Café', 'Massa folhada'],
#  ['Hearty & Seasonal', 'Café', 'Muffin'],
#  ['Pão'],
#  ['Café'],
#  ['Escandinavo'],
#  ['Sopa', 'Café'],
#  ['Café', 'Biscoitos', 'Hambúrguer no prato'],
#  ['Pão'],
#  ['Pão', 'Chá', 'Chá'],
#  ['Massa folhada', 'Café'],
#  ['Hambúrguer no prato', 'Café'],
#  ['Pão', 'Biscoitos'],
#  ['Sanduíche'],
#  ['Hambúrguer no prato'],
#  ['Pão', 'Massa folhada'],
#  ['Pão', 'Escandinavo'],
#  ['Escandinavo'],
#  ['Alfajores', 'Café'],
#  ['Café'],
#  ['Café', 'Coca-Cola', 'Sopa'],
#  ['Bolo'],
#  ['Chá', 'Sanduíche', 'Sopa'],
#  ['Café'],
#  ['Hearty & Seasonal', 'Pão'],
#  ['Alfajores'],
#  ['Bolo'],
#  ['Chá', 'Chá', 'Pão'],
#  ['Café', 'Chá', 'Pão', 'Sopa'],
#  ['Café', 'Café'],
#  ['Escandinavo'],
#  ['Fudge'],
#  ['Café', 'Sanduíche'],
#  ['Chá', 'Pão', 'Biscoitos', 'Massa folhada'],
#  ['Muffin'],
#  ['Escandinavo'],
#  ['Geléia', 'Chá'],
#  ['Suco', 'Chá', 'Alfajores'],
#  ['Bolo', 'Muffin', 'Café', 'Sopa'],
#  ['Chocolate quente', 'Bolo', 'Café'],
#  ['Bolo', 'Biscoitos'],
#  ['Chá', 'Pão'],
#  ['Alfajores', 'Café', 'Café', 'Café', 'Suco'],
#  ['Café', 'Chá', 'Sopa'],
#  ['Chocolate quente'],
#  ['Biscoitos'],
#  ['Café', 'Medialuna'],
#  ['Pão', 'Ovos'],
#  ['Escandinavo'],
#  ['Medialuna'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Café', 'Pão'],
#  ['Pão', 'Café', 'Massa folhada'],
#  ['Café', 'Massa folhada'],
#  ['Massa folhada'],
#  ['Café'],
#  ['Café'],
#  ['Café', 'Chocolate quente', 'Massa folhada'],
#  ['Coca-Cola'],
#  ['Café', 'Geléia'],
#  ['Chá'],
#  ['Pão', 'Massa folhada'],
#  ['Café', 'Alfajores', 'Farm House'],
#  ['Chá', 'Massa folhada'],
#  ['Pão'],
#  ['Café', 'Geléia'],
#  ['Café', 'Chá', 'Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Café', 'Pão', 'Massa folhada'],
#  ['Farm House'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Café', 'Massa folhada'],
#  ['Café'],
#  ['Café', 'Massa folhada'],
#  ['Pão', 'Pão'],
#  ['Pão', 'Café', 'Massa folhada'],
#  ['Massa folhada', 'Café'],
#  ['Café', 'Farm House'],
#  ['Farm House', 'Farm House', 'Massa folhada'],
#  ['Pão', 'Suco', 'Alfajores'],
#  ['Café', 'Massa folhada'],
#  ['Pão', 'Alfajores'],
#  ['Pão'],
#  ['Café', 'Biscoitos'],
#  ['Café'],
#  ['Biscoitos'],
#  ['Hearty & Seasonal'],
#  ['Café'],
#  ['Geléia', 'Hambúrguer no prato', 'Pão'],
#  ['Farm House', 'Escandinavo'],
#  ['Hearty & Seasonal', 'Café', 'Muffin', 'Escandinavo'],
#  ['Hambúrguer no prato', 'Tigelas variadas', 'Café', 'Coca-Cola'],
#  ['Pão'],
#  ['Escandinavo', 'Farm House', 'Alfajores', 'Café', 'Café'],
#  ['Suco', 'Água mineral', 'Sopa'],
#  ['Sopa', 'Chá'],
#  ['Suco', 'Chá', 'Biscoitos', 'Sopa'],
#  ['Hearty & Seasonal', 'Chá'],
#  ['Fudge'],
#  ['Café', 'Água mineral', 'Suco', 'Sopa'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Smoothies'],
#  ['Hearty & Seasonal', 'Chá'],
#  ['Café', 'Sanduíche', 'Sanduíche'],
#  ['Biscoitos', 'Farm House'],
#  ['Sopa', 'Chá', 'Suco'],
#  ['Sopa'],
#  ['Café'],
#  ['Pão'],
#  ['Biscoitos', 'Chá'],
#  ['Sopa', 'Hearty & Seasonal', 'Pão'],
#  ['Café'],
#  ['Café'],
#  ['Café', 'Chá'],
#  ['Pão'],
#  ['Chá'],
#  ['Café', 'Chá'],
#  ['Café'],
#  ['Fudge'],
#  ['Chá'],
#  ['Sopa', 'Chá'],
#  ['Suco'],
#  ['Alfajores'],
#  ['Pão'],
#  ['Café', 'Alfajores'],
#  ['Suco', 'Alfajores', 'Biscoitos', 'Tigelas variadas', 'Água mineral'],
#  ['Café', 'Alfajores'],
#  ['Fudge'],
#  ['Whey Protein', 'Suco'],
#  ['Café', 'Água mineral', 'Alfajores'],
#  ['Whey Protein', 'Café'],
#  ['Alfajores'],
#  ['Café', 'Pão'],
#  ['Medialuna', 'Medialuna'],
#  ['Medialuna', 'Pão'],
#  ['Farm House'],
#  ['Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Café', 'Café', 'Massa folhada', 'Massa folhada', 'Café'],
#  ['Medialuna'],
#  ['Pão', 'Chá', 'Sanduíche'],
#  ['Pão'],
#  ['Geléia', 'Café', 'Farm House'],
#  ['Focaccia'],
#  ['Pão'],
#  ['Hambúrguer no prato', 'Massa folhada', 'Pão', 'Suco de frutas'],
#  ['Farm House', 'Massa folhada'],
#  ['Pão', 'Massa folhada'],
#  ['Massa folhada', 'Pão'],
#  ['Geléia', 'Café'],
#  ['Farm House'],
#  ['Pão', 'Massa folhada'],
#  ['Café', 'Chá', 'Pão'],
#  ['Geléia'],
#  ['Massa folhada', 'Medialuna', 'Medialuna'],
#  ['Café'],
#  ['Chá'],
#  ['Pão'],
#  ['Pão', 'Massa folhada'],
#  ['Massa folhada'],
#  ['Farm House'],
#  ['Chá'],
#  ['Café', 'Brownie', 'Alfajores', 'Fudge'],
#  ['Pão', 'Fudge', 'Biscoitos'],
#  ['Café'],
#  ['Pão'],
#  ['Café', 'Café', 'Geléia', 'Massa folhada'],
#  ['Sopa', 'Café'],
#  ['Smoothies', 'Sopa', 'Hearty & Seasonal', 'Massa folhada'],
#  ['Massa folhada', 'Pão'],
#  ['Massa folhada', 'Medialuna'],
#  ['Chá', 'Café'],
#  ['Pão', 'Biscoitos'],
#  ['Café',
#   'Café',
#   'Pão',
#   'Hearty & Seasonal',
#   'Tigelas variadas',
#   'Sanduíche',
#   'Focaccia'],
#  ['Café'],
#  ['Café', 'Sanduíche', 'Brownie'],
#  ['Brownie', 'Biscoitos'],
#  ['Café'],
#  ['Café'],
#  ['Sanduíche', 'Pão', 'Café'],
#  ['Café', 'Chocolate quente'],
#  ['Chá'],
#  ['Sanduíche', 'Café', 'Brownie'],
#  ['Brownie', 'Massa folhada', 'Focaccia', 'Farm House'],
#  ['Bolo', 'Focaccia'],
#  ['Sopa', 'Hearty & Seasonal', 'Água mineral'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Café'],
#  ['Chá', 'Bolo'],
#  ['Café', 'Sopa'],
#  ['Pão', 'Focaccia', 'Fudge'],
#  ['Chocolate quente', 'Café', 'Alfajores'],
#  ['Brownie', 'Massa folhada', 'Bolo'],
#  ['Medialuna', 'Alfajores', 'Doce de leite'],
#  ['Doce de leite', 'Alfajores'],
#  ['Pão', 'Bolo'],
#  ['Bolo', 'Café'],
#  ['Pão'],
#  ['Sanduíche'],
#  ['Pão', 'Café', 'Alfajores', 'Medialuna'],
#  ['Café'],
#  ['Pão', 'Alfajores'],
#  ['Chá', 'Café'],
#  ['Pão'],
#  ['Doce de leite'],
#  ['Farm House'],
#  ['Fudge'],
#  ['Café'],
#  ['Café', 'Alfajores', 'Suco', "Ella's Kitchen Pouches", 'Brownie'],
#  ['Alfajores'],
#  ['Alfajores', 'Brownie', 'Biscoitos', 'Pão', 'Suco'],
#  ['Bolo', 'Biscoitos'],
#  ['Tigelas variadas'],
#  ['Café'],
#  ['Farm House'],
#  ['Chá'],
#  ['Café'],
#  ['Focaccia', 'Farm House'],
#  ['Doce de leite'],
#  ['Suco', 'Suco de frutas', "Ella's Kitchen Pouches", 'Biscoitos'],
#  ['Pão'],
#  ['Chocolate quente'],
#  ['Café'],
#  ['Café'],
#  ['Café'],
#  ['Medialuna'],
#  ['Pão', 'Chá', 'Geléia'],
#  ['Farm House'],
#  ['Pão'],
#  ['Café'],
#  ['Medialuna', 'Café'],
#  ['Pão'],
#  ['Medialuna', 'Massa folhada', 'Medialuna'],
#  ['Café', 'Café', 'Geléia'],
#  ['Pão', 'Café'],
#  ['Café', 'Café'],
#  ['Pão'],
#  ['Chocolate quente'],
#  ['Pão', 'Medialuna'],
#  ['Pão', 'Geléia'],
#  ['Geléia', 'Pão'],
#  ['Café', 'Pão'],
#  ['Pão', 'Farm House'],
#  ['Pão', 'Café', 'Café'],
#  ['Chá', 'Massa folhada'],
#  ['Café', 'Café'],
#  ['Pão'],
#  ['Massa folhada', 'Brownie'],
#  ['Farm House'],
#  ['Café'],
#  ['Chá', 'Café', 'Mel', 'Biscoitos'],
#  ['Chá'],
#  ['Pão'],
#  ['Brownie'],
#  ['Pão', 'Café'],
#  ['Pão'],
#  ['Café'],
#  ['Chá', 'Chá'],
#  ['Chá'],
#  ['Café', 'Café'],
#  ['Pão', 'Café'],
#  ['Pão', 'Pão'],
#  ['Pão', 'O BART'],
#  ['Café', 'Brownie'],
#  ['Café'],
#  ['Café', 'Brownie'],
#  ['Água mineral', 'Café', 'Café', 'Hambúrguer no prato'],
#  ['Brownie', 'Café'],
#  ['Brownie', 'Suco'],
#  ['Café',
#   'Café',
#   'Pão',
#   'Chá',
#   'Alfajores',
#   'Medialuna',
#   'Massa folhada',
#   'Geléia'],
#  ['Pão'],
#  ['Fudge', 'Fudge'],
#  ['Café', 'Tigelas variadas'],
#  ['Massa folhada', 'Pão'],
#  ['Sopa', 'Escandinavo', 'Café', 'Água mineral'],
#  ['Suco', 'Água mineral', 'Sanduíche', 'Tigelas variadas'],
#  ['Pão', 'Massa folhada', 'Pão'],
#  ['Hearty & Seasonal', 'Hearty & Seasonal', 'Café', 'Café'],
#  ['Pão', 'Hearty & Seasonal', 'Café', 'Água mineral'],
#  ['Café', 'Hambúrguer no prato', 'Sanduíche', 'Brownie'],
#  ['Café', 'Brownie'],
#  ['Alfajores', 'Café', 'Hambúrguer no prato'],
#  ['Whey Protein', 'Café'],
#  ['Café', 'Chocolate quente'],
#  ['Sopa', 'Geléia', 'Café', 'Café'],
#  ['Água mineral', 'Brownie'],
#  ['Escandinavo', 'Café'],
#  ['Escandinavo', 'Café'],
#  ['Café', 'Café'],
#  ['Café', 'Café', 'Chocolate quente', 'Brownie', 'Hearty & Seasonal'],
#  ['Chá', 'Bolo'],
#  ['Medialuna'],
#  ['Alfajores', 'Chá', 'Café'],
#  ['Café', 'Suco', 'Brownie', 'Alfajores'],
#  ['Café', 'Sanduíche'],
#  ['Pão', 'Sopa'],
#  ['Sopa', 'Pão'],
#  ['Pão'],
#  ['Chá', 'Brownie', 'Biscoitos'],
#  ['Café', 'Pão', 'Brownie'],
#  ['Brownie'],
#  ['Biscoitos', 'Pão', 'Geléia'],
#  ['Café'],
#  ['Chá', 'Brownie', 'Chá'],
#  ['Alfajores', 'Medialuna', 'Escandinavo'],
#  ['Chocolate quente', 'Café', 'Alfajores', 'Biscoitos'],
#  ['Brownie'],
#  ['Fudge'],
#  ['Chá', 'Brownie'],
#  ['Doce de leite', 'Fudge'],
#  ['Pão', 'Escandinavo', 'Fudge', 'Granola', 'Massa folhada', 'Café'],
#  ['Pão', 'Fudge'],
#  ['Chocolate quente', 'Café', 'Medialuna', 'Medialuna'],
#  ['Pão'],
#  ['Pão', 'Medialuna'],
#  ['Pão', 'Café', 'Medialuna', 'Geléia'],
#  ['Geléia', 'Café', 'Brownie'],
#  ['Pão', 'Café', 'Geléia'],
#  ['Escandinavo'],
#  ['Café', 'Biscoitos'],
#  ['Café', 'Café', 'Escandinavo'],
#  ['Pão'],
#  ['Pão'],
#  ['Geléia', 'Brownie', 'Café', 'Café'],
#  ['Café'],
#  ['Brownie', 'Chocolate quente'],
#  ['Pão'],
#  ['Pão', 'Pão', 'Medialuna'],
#  ['Café', 'Chocolate quente', 'Brownie'],
#  ['Escandinavo'],
#  ['Cesto', 'Pão'],
#  ['Café', 'Pão', 'Brownie'],
#  ['Bolo', 'Fudge'],
#  ['Café', 'Chocolate quente', 'Café', 'Cesto'],
#  ['Escandinavo'],
#  ['Escandinavo'],
#  ['Café', 'Pão', 'Café', 'Bolo', 'Medialuna'],
#  ['Café', 'Café', 'Medialuna'],
#  ['Pão', 'Massa folhada'],
#  ['Pão', 'Brownie'],
#  ['Medialuna', 'Farm House'],
#  ['Pão', 'Medialuna'],
#  ['Brownie', 'Medialuna', 'Chocolate quente', 'Smoothies', 'Café'],
#  ['Pão', 'Chá', 'Café', 'Brownie', 'Medialuna'],
#  ['Medialuna', 'Medialuna', 'Biscoitos'],
#  ['Café', 'Medialuna'],
#  ['Pão', 'Fudge'],
#  ['Café', 'Chá'],
#  ['Café', 'Biscoitos'],
#  ['Massa folhada', 'Pão', 'Brownie'],
#  ['Pão', 'Café', 'Pão'],
#  ['Café', 'Café', 'Chá'],
#  ['Pão'],
#  ['Medialuna', 'Café'],
#  ['Suco de frutas', 'Café', 'Brownie'],
#  ['Café', 'Fudge'],
#  ['Café'],
#  ['Café', 'Cesto'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Café', 'Brownie'],
#  ['Escandinavo', 'Brownie', 'Suco de frutas'],
#  ['Hambúrguer no prato', 'Café', 'Chocolate quente', 'Brownie'],
#  ['Brownie', 'Pão', 'Chocolate quente'],
#  ['Geléia', 'Fudge'],
#  ['Café'],
#  ['Fudge'],
#  ['Whey Protein', 'Hearty & Seasonal', 'Café', 'Chá', 'Bolo'],
#  ['Café'],
#  ['Escandinavo'],
#  ['Bolo', 'Bolo esponja vitoriano', 'Escandinavo'],
#  ['Chá', 'Bolo'],
#  ['Café', 'Café'],
#  ['Café', 'Café'],
#  ['Pão'],
#  ['Frittata'],
#  ['Café', 'Café', 'Suco de frutas', 'Brownie'],
#  ['Focaccia', 'Fairy Doors'],
#  ['Chá', 'Café', 'Café'],
#  ['Chocolate quente', 'Hearty & Seasonal', 'Tigelas variadas', 'Brownie'],
#  ['Frittata', 'Café'],
#  ['Pão', 'Brownie'],
#  ['Frittata'],
#  ['Escandinavo'],
#  ['Pão'],
#  ['Farm House'],
#  ['Tigelas variadas', 'Geléia', 'Sopa', 'Brownie'],
#  ['Hearty & Seasonal', 'Café', 'Chá'],
#  ['Pão'],
#  ['Pão', 'Frittata'],
#  ['Escandinavo'],
#  ['Hambúrguer no prato', 'Chocolate quente', 'Café'],
#  ['Café', 'Whey Protein'],
#  ['Frittata', 'Café'],
#  ['Escandinavo'],
#  ['Hearty & Seasonal', 'Café', 'Água mineral'],
#  ['Escandinavo'],
#  ['Pão', 'Café'],
#  ['Hearty & Seasonal', 'Sopa', 'Pão', 'Café'],
#  ['Brownie', 'Bolo', 'Chá'],
#  ['Whey Protein', 'Café'],
#  ['Café', 'Chá', 'Brownie', 'Sopa'],
#  ['Bolo'],
#  ['Chocolate quente', 'Café', 'Bolo'],
#  ['Hearty & Seasonal', 'Café'],
#  ['Café'],
#  ['Frittata', 'Café', 'Brownie'],
#  ['Sanduíche', 'Frittata', 'Coca-Cola', 'Água mineral', 'Brownie'],
#  ['Granola', 'Escandinavo'],
#  ['Café', 'Coca-Cola', 'Café'],
#  ['Chá', 'Chá', 'Brownie', 'Bolo'],
#  ['Fudge'],
#  ['Café'],
#  ['Brownie'],
#  ['Bolo'],
#  ['Chá'],
#  ['Café', 'Café', 'Café', 'Sopa', 'Sanduíche', 'Bolo'],
#  ['Café', 'Pão', 'Brownie'],
#  ['Pão', 'Café', 'Brownie'],
#  ['Café', 'Pão', 'Brownie'],
#  ['Brownie', 'Café'],
#  ['Café', 'Sopa', 'Brownie'],
#  ['Fudge'],
#  ['Pão', 'Focaccia'],
#  ['Pão', 'Farm House', 'Geléia'],
#  ['Chocolate quente', 'Brownie'],
#  ['Chocolate quente'],
#  ['Café', 'Brownie'],
#  ['Medialuna', 'Massa folhada'],
#  ['Pão'],
#  ['Café', 'Massa folhada', 'Pão'],
#  ['Café', 'Água mineral'],
#  ['Massa folhada', 'Pão', 'Chocolate quente'],
#  ['Pão'],
#  ['Pão'],
#  ['Geléia', 'Café', 'Café', 'Pão'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Medialuna', 'Café', 'Café', 'Focaccia', 'Hearty & Seasonal'],
#  ['Pão', 'Farm House', 'Café', 'Geléia'],
#  ['Farm House'],
#  ['Café', 'Chá', 'Massa folhada', 'Medialuna'],
#  ['Massa folhada', 'Medialuna', 'Café'],
#  ['Café', 'Chocolate quente', 'Cesto', 'Farm House'],
#  ['Massa folhada', 'Farm House'],
#  ['Chocolate quente', 'Café', 'Suco de frutas'],
#  ['Massa folhada', 'Medialuna', 'Muffin'],
#  ['Farm House'],
#  ['Muffin', 'Massa folhada', 'Focaccia'],
#  ['Café', 'Chá'],
#  ['Pão'],
#  ['Focaccia'],
#  ['Café', 'Chocolate quente', 'Massa folhada', 'Geléia'],
#  ['Pão'],
#  ['Café', 'Massa folhada', 'Pão'],
#  ['Chá'],
#  ['Chocolate quente', 'Café', 'Água mineral'],
#  ['Café', 'Café'],
#  ['Café'],
#  ['Geléia', 'Café', 'Café'],
#  ['Muffin'],
#  ['Pão'],
#  ['Pão'],
#  ['Pão'],
#  ['Muffin', 'Chocolate quente', 'Café'],
#  ['Muffin', 'Fudge'],
#  ['Pão'],
#  ['Pão'],
#  ['Farm House'],
#  ['Café', 'Muffin'],
#  ['Focaccia'],
#  ['Pão', 'Chá'],
#  ['Café', 'Chocolate quente'],
#  ['Café', 'Hambúrguer no prato', 'Café', 'Tigelas variadas', 'Geléia'],
#  ['Geléia'],
#  ['Hambúrguer no prato'],
#  ['Pão', 'Café'],
#  ['Café',
#   'Café',
#   'Água mineral',
#   'Suco',
#   'Hambúrguer no prato',
#   'Tigelas variadas'],
#  ['Pão', 'Chá', 'Suco'],
#  ['Café', 'Café', 'Bolo'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Bolo', 'Brownie', 'Café', 'Café'],
#  ['Focaccia', 'Café'],
#  ['Chá', 'Café', 'Muffin'],
#  ['Café'],
#  ['Chá', 'Café'],
#  ['Hearty & Seasonal', 'Bolo', 'Café'],
#  ['Pão', 'Chá', 'Bolo'],
#  ['Whey Protein', 'Café'],
#  ['Chocolate quente', 'Muffin'],
#  ['Café', 'Café', 'Sopa', 'Whey Protein'],
#  ['Geléia'],
#  ['Café', 'Alfajores'],
#  ['Bolo', 'Chocolate quente', 'Alfajores'],
#  ['Chocolate quente', 'Chá', 'Muffin'],
#  ['Brownie'],
#  ['Bolo', 'Café'],
#  ['Bolo esponja vitoriano', 'Alfajores', 'Chá'],
#  ['Pão'],
#  ['Hambúrguer no prato', 'Chá', 'Hambúrguer no prato'],
#  ['Whey Protein', 'Chá'],
#  ['Pão', 'Fudge'],
#  ['Medialuna', 'Hambúrguer no prato', 'Café'],
#  ['Massa folhada', 'Pão'],
#  ['Massa folhada', 'Pão'],
#  ['Café', 'Chá', 'Alfajores', 'Alfajores'],
#  ['Alfajores', 'Alfajores', 'Café'],
#  ['Café', 'Alfajores'],
#  ['Alfajores', 'Massa folhada'],
#  ['Alfajores'],
#  ['Massa folhada', 'Chá', 'Alfajores', 'Hearty & Seasonal'],
#  ['Chá', 'Sanduíche'],
#  ['Empanadas', 'Chá'],
#  ['Alfajores', 'Alfajores', 'Chá'],
#  ['Alfajores'],
#  ['Massa folhada', 'Doce de leite'],
#  ['Café', 'Massa folhada'],
#  ['Farm House', 'Café'],
#  ['Pão', 'Escandinavo', 'Medialuna'],
#  ['Pão'],
#  ['Massa folhada', 'Chá', 'Alfajores'],
#  ['Massa folhada', 'Café'],
#  ['Pão', 'Massa folhada', 'Muffin', 'Farm House'],
#  ['Medialuna', 'Chá'],
#  ['Alfajores'],
#  ['Sanduíche', 'Chá'],
#  ['Chá', 'Pão'],
#  ['Pão', 'Café', 'Massa folhada'],
#  ['Café', 'Café', 'Muffin', 'Alfajores', 'Empanadas'],
#  ['Café'],
#  ['Pão'],
#  ['Café'],
#  ['Café'],
#  ['Pão'],
#  ['Pão', 'Massa folhada', 'Medialuna', 'Chá'],
#  ['Chá', 'Pão'],
#  ['Muffin'],
#  ['Café', 'Muffin'],
#  ['Café', 'Pão', 'Massa folhada', 'Medialuna'],
#  ['Café', 'Café', 'Muffin'],
#  ['Muffin', 'Chocolate quente', 'Escandinavo', 'Pão'],
#  ['Farm House'],
#  ['Muffin'],
#  ['Café'],
#  ['Pão'],
#  ['Café', 'Café', 'Biscoitos'],
#  ['Café', 'Café'],
#  ['Muffin'],
#  ['Café', 'Chá', 'Keeping It Local'],
#  ['Café', 'Medialuna'],
#  ['Pão'],
#  ['Hambúrguer no prato', 'Escandinavo'],
#  ['Café', 'Chá'],
#  ['Pão'],
#  ['Café', 'Coca-Cola'],
#  ['Café', 'Muffin'],
#  ['Café', 'Pão', 'Café', 'Medialuna', 'Muffin', 'Escandinavo'],
#  ['Pão'],
#  ['Coca-Cola'],
#  ['Pão', 'Escandinavo'],
#  ['Café'],
#  ['Pão'],
#  ['Escandinavo', 'Pão'],
#  ['Fudge', 'Fudge'],
#  ['Sopa', 'Hearty & Seasonal', 'Café'],
#  ['Coca-Cola'],
#  ['Café', 'Biscoitos', 'Chá'],
#  ['Massa folhada', 'Chá', 'Café'],
#  ['Pão'],
#  ['Café', 'Medialuna'],
#  ['Café', 'Café', 'Muffin', 'Sanduíche', 'Sopa'],
#  ['Chá', 'Café', 'Muffin'],
#  ['Alfajores'],
#  ['Pão'],
#  ['Café', 'Medialuna'],
#  ['Café'],
#  ['Café'],
#  ['Medialuna'],
#  ['Empanadas', 'Pão', 'Escandinavo'],
#  ['Café', 'Hambúrguer no prato'],
#  ['Chá'],
#  ['Escandinavo'],
#  ['Muffin'],
#  ['Escandinavo', 'Pão'],
#  ['Pão'],
#  ['Café'],
#  ['Pão'],
#  ['Pão'],
#  ['Café', 'Café'],
#  ['Biscoitos', 'Escandinavo'],
#  ['Café', 'Pão', 'Empanadas', 'Medialuna'],
#  ['Café', 'Massa folhada'],
#  ['Pão'],
#  ['Massa folhada', 'Chá'],
#  ['Café', 'Café', 'Massa folhada'],
#  ['Café', 'Pão'],
#  ['Café', 'Keeping It Local'],
#  ['Fudge'],
#  ['Hambúrguer no prato', 'Café', 'Café'],
#  ['Chocolate quente', 'Café', 'Massa folhada', 'Medialuna'],
#  ['Alfajores', 'Café'],
#  ['Café'],
#  ['Café', 'Café', 'Medialuna'],
#  ['Coca-Cola'],
#  ['Café', 'Café', 'Alfajores'],
#  ['Muffin'],
#  ['Farm House', 'Brownie', 'Fudge'],
#  ['Café', 'Café'],
#  ['Chá', 'Muffin', 'Farm House'],
#  ['Café', 'Massa folhada'],
#  ['Massa folhada', 'Brownie'],
#  ['Medialuna'],
#  ['Café'],
#  ['Massa folhada', 'Café', 'Suco'],
#  ['Café', 'Pão'],
#  ['Chá', 'Café'],
#  ['Chá', 'Alfajores'],
#  ['Alfajores', 'Café'],
#  ['Escandinavo'],
#  ['Massa folhada', 'Medialuna'],
#  ['Brownie'],
#  ['Farm House'],
#  ['Café', 'Biscoitos'],
#  ['Sopa'],
#  ['Bandeja de arte', 'Café', 'Café', 'Brownie'],
#  ['Café'],
#  ['Farm House'],
#  ['Sopa', 'Bandeja de arte', 'Alfajores', 'Frittata'],
#  ['Sanduíche', 'Café'],
#  ['Chá'],
#  ['Farm House'],
#  ['Escandinavo', 'Muffin'],
#  ['Farm House'],
#  ['Escandinavo'],
#  ['Sopa'],
#  ['Hearty & Seasonal', 'Chá', 'Pão'],
#  ['Chocolate quente'],
#  ['Café', 'Sanduíche', 'Hearty & Seasonal'],
#  ['Brownie', 'Hearty & Seasonal', 'Sanduíche', 'Café'],
#  ['Medialuna', 'Café'],
#  ['Café', 'Brownie', 'Sopa'],
#  ['Sanduíche', 'Sanduíche', 'Alfajores', 'Alfajores', 'Focaccia'],
#  ['Farm House', 'Hambúrguer no prato'],
#  ['Pão'],
#  ['Café'],
#  ['Chocolate quente', 'Chá', 'Muffin'],
#  ['Massa folhada'],
#  ['Café', 'Brownie', 'Hearty & Seasonal', 'Sopa', 'Tigela Nic Pitt'],
#  ['Café'],
#  ['Alfajores', 'Medialuna', 'Escandinavo', 'Farm House'],
#  ['Sopa', 'Café'],
#  ['Chá', 'Chá'],
#  ['Café', 'Chá', 'Biscoitos'],
#  ['Chá', 'Muffin'],
#  ['Café', 'Café', 'Brownie'],
#  ['Café'],
#  ['Café'],
#  ['Café'],
#  ['Farm House'],
#  ['Café', 'Pudim de pão'],
#  ['Café', 'Medialuna'],
#  ['Chocolate quente'],
#  ['Café', 'Chocolate quente', 'Farm House'],
#  ['Massa folhada', 'Café'],
#  ['Pão'],
#  ['Massa folhada', 'Café'],
#  ['Café', 'Café'],
#  ['Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Pão'],
#  ['Café', 'Chocolate quente'],
#  ['Pão'],
#  ['Café', 'Focaccia', 'Café', 'Medialuna', 'Pão'],
#  ['Café'],
#  ['Pão', 'Keeping It Local'],
#  ['Pão', 'Café'],
#  ['Pão'],
#  ['Pão', 'Medialuna'],
#  ['Café'],
#  ['Café', 'Café', 'Medialuna'],
#  ['Café', 'Biscoitos', 'Hambúrguer no prato'],
#  ['Chá', 'Pão'],
#  ['Pão', 'Keeping It Local', 'Café'],
#  ['Café', 'Medialuna'],
#  ['Café', 'Medialuna'],
#  ['Chá'],
#  ['Suco', 'Coca-Cola', 'Sopa'],
#  ['Pão'],
#  ['Brownie'],
#  ['Brownie', 'Pão', 'Café'],
#  ['Café', 'Massa folhada', 'Pão', 'Hearty & Seasonal'],
#  ['Pão', 'Café', 'Brownie'],
#  ['Café'],
#  ['Pão', 'Biscoitos'],
#  ['Fudge', 'Ovos'],
#  ['Pão'],
#  ['Pão', 'Muffin'],
#  ['Sopa'],
#  ['Café', 'Pudim de pão'],
#  ['Pão', 'Hambúrguer no prato'],
#  ['Sanduíche', 'Café', 'Fudge', 'Geléia', 'Pudim de pão'],
#  ['Pudim de pão', 'Sopa', 'Café'],
#  ['Hearty & Seasonal', 'Pão'],
#  ['Café', 'Café', 'Biscoitos'],
#  ['Café'],
#  ['Pão'],
#  ['Café', 'Pão', 'Sopa'],
#  ['Sopa', 'Chá', 'Focaccia'],
#  ['Café', 'Suco de frutas', 'Biscoitos'],
#  ['Café', 'Café'],
#  ['Café', 'Sanduíche', 'Chá'],
#  ['Escandinavo'],
#  ['Adjustment'],
#  ['Café'],
#  ['Medialuna', 'Café'],
#  ['Pão'],
#  ['Pão'],
#  ['Café', 'Massa folhada'],
#  ['Farm House'],
#  ['Medialuna', 'Brownie'],
#  ['Pão', 'Massa folhada', 'Brownie'],
#  ['Massa folhada', 'Pão', 'Biscoitos'],
#  ['Pão', 'Pão'],
#  ['Biscoitos', 'Massa folhada', 'Café', 'Suco'],
#  ['Massa folhada', 'Biscoitos', 'Café'],
#  ['Café', 'Medialuna'],
#  ['Pão'],
#  ['Hambúrguer no prato', 'Café'],
#  ['Café', 'Medialuna'],
#  ['Pão'],
#  ['Pão', 'Café', 'Alfajores', 'Biscoitos'],
#  ['Pão', 'Café', 'Café'],
#  ['Pão'],
#  ['Pão', 'Café', 'Chá', 'Keeping It Local', 'Geléia', 'Biscoitos'],
#  ['Massa folhada', 'Café', 'Suco'],
#  ['Medialuna', 'Pão', 'Focaccia'],
#  ['Massa folhada', 'Medialuna', 'Café'],
#  ['Café'],
#  ['Café'],
#  ['Café', 'Biscoitos', 'Trufas', 'Brownie', 'Pão'],
#  ['Bandeja de arte', 'Chá'],
#  ['Pão'],
#  ['Café'],
#  ['Café', 'Biscoitos'],
#  ['Brownie'],
#  ['Pão', 'Chá', 'Empanadas'],
#  ['Pão', 'Chocolate quente'],
#  ['Café', 'Biscoitos'],
#  ['Pão'],
#  ['Hambúrguer no prato', 'Sanduíche', 'Chá', 'Pão'],
#  ['Sopa', 'Sanduíche', 'Pão'],
#  ['Sopa', 'Pão'],
#  ['Fudge'],
#  ['Café'],
#  ['Café', 'Empanadas', 'Sopa'],
#  ['Pão', 'Café', 'Brownie'],
#  ['Café', 'Smoothies', 'Suco', 'Sopa', 'Hearty & Seasonal'],
#  ['Alfajores',
#   'Sanduíche',
#   'Chocolate quente',
#   'Café',
#   'Escandinavo',
#   'Biscoitos'],
#  ['Chá', 'Café'],
#  ['Pão', 'Biscoitos'],
#  ['Alfajores', 'Biscoitos', 'Pão', 'Pão'],
#  ['Chá', 'Brownie'],
#  ['Chá', 'Pão'],
#  ['Café', 'Alfajores'],
#  ['Pão'],
#  ['Empanadas', 'Café'],
#  ['Pão'],
#  ['Café', 'Chocolate quente'],
#  ['Café'],
#  ['Café', 'Brownie'],
#  ['Chá', 'Chocolate quente', 'Brownie', 'Trufas'],
#  ['Café', 'Keeping It Local'],
#  ['Café'],
#  ['Alfajores'],
#  ['Escandinavo', 'Óleo de chimichurri'],
#  ['Pão', 'Trufas'],
#  ['Brownie', 'Focaccia'],
#  ['Café', 'Pão'],
#  ['Café', 'Chá', 'Bandeja de arte', 'Biscoitos'],
#  ['Café'],
#  ['Pão'],
#  ['Café', 'Alfajores', 'Alfajores', 'Coca-Cola'],
#  ['Pão'],
#  ['Pão'],
#  ['Pão', 'Massa folhada', 'Medialuna', 'Café'],
#  ['Café'],
#  ['Pão', 'Keeping It Local'],
#  ['Pão'],
#  ['Café', 'Escandinavo'],
#  ['Pão', 'Farm House', 'Massa folhada', 'Medialuna'],
#  ['Medialuna'],
#  ['Café'],
#  ['Pão', 'Farm House'],
#  ['Pão'],
#  ['Keeping It Local', 'Pão'],
#  ...]

# %%
#Aplicando o encoding

te = TransactionEncoder()
te_ary = te.fit(carrinhos).transform(carrinhos)
te_ary
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Criando um novo DF a partir do encoding

df_carrinho = pd.DataFrame(te_ary, columns=te.columns_)
df_carrinho
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Adjustment  Afternoon with the baker  Alfajores  Argentina Night  Bacon  \
# 0          False                     False      False            False  False
# 1          False                     False      False            False  False
# 2          False                     False      False            False  False
# 3          False                     False      False            False  False
# 4          False                     False      False            False  False
# ...          ...                       ...        ...              ...    ...
# 9460       False                     False      False            False  False
# 9461       False                     False      False            False  False
# 9462       False                     False      False            False  False
# 9463       False                     False      False            False  False
# 9464       False                     False      False            False  False
#
#       Baguete  Bakewell  Bandeja de arte  Banquete vegano  Batatas fritas  \
# 0       False     False            False            False           False
# 1       False     False            False            False           False
# 2       False     False            False            False           False
# 3       False     False            False            False           False
# 4       False     False            False            False           False
# ...       ...       ...              ...              ...             ...
# 9460    False     False            False            False           False
# 9461    False     False            False            False           False
# 9462    False     False            False            False           False
# 9463    False     False            False            False           False
# 9464    False     False            False            False           False
#
#       ...  Tigela Nic Pitt  Tigelas variadas  Torrada  Torta vegana de carne  \
# 0     ...            False             False    False                  False
# 1     ...            False             False    False                  False
# 2     ...            False             False    False                  False
# 3     ...            False             False    False                  False
# 4     ...            False             False    False                  False
# ...   ...              ...               ...      ...                    ...
# 9460  ...            False             False    False                  False
# 9461  ...            False             False    False                  False
# 9462  ...            False             False    False                  False
# 9463  ...            False             False    False                  False
# 9464  ...            False             False    False                  False
#
#       Trufas  Vale-presente  Whey Protein  Xarope de gengibre  Água mineral  \
# 0      False          False         False               False         False
# 1      False          False         False               False         False
# 2      False          False         False               False         False
# 3      False          False         False               False         False
# 4      False          False         False               False         False
# ...      ...            ...           ...                 ...           ...
# 9460   False          False         False               False         False
# 9461    True          False         False               False         False
# 9462   False          False         False               False         False
# 9463   False          False         False               False         False
# 9464   False          False         False               False         False
#
#       Óleo de chimichurri
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 9460                False
# 9461                False
# 9462                False
# 9463                False
# 9464                False
#
# [9465 rows x 94 columns]

# %% [markdown]
# Com nosso DF devidamente preparado, podemos obter a combinação de itens frequentes.
#
# Precisamos passar qual o limite mínimo (*treshold*) que um conjunto aparece no universo amostral para poder ser incluido na lista de *itens frequentes*.
#
# Por padrão, o Apriori considera esse limite como sendo 0.5. Mas testando esse limite, nenhum item/conjunto aparece. Após algumas tentativas, vamos considerar nosso limite mínimo 0.01 (ou seja, estamos pedindo para o algoritimo nos trazer quais itens e conjuntos aparecem em pelo menos 1% dos carrinhos).

# %%
#Obtendo a lista de frequência de cada combinação

pd.set_option('display.precision', 2) #Mostra os resultados apenas com duas casas decimais

freq_items = apriori(df_carrinho, min_support= 0.01, use_colnames = True)
freq_items.sort_values('support', ascending = False).head(10).reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    support            itemsets
# 0     0.48              (Café)
# 1     0.33               (Pão)
# 2     0.14               (Chá)
# 3     0.10              (Bolo)
# 4     0.09         (Pão, Café)
# 5     0.09     (Massa folhada)
# 6     0.07         (Sanduíche)
# 7     0.06         (Medialuna)
# 8     0.06  (Chocolate quente)
# 9     0.05        (Bolo, Café)

# %% [markdown]
# **Observações:**
#
# > O item mais frquente no nosso dataset é o Café, que aparece em 47.8% de todos os tickets. Logo em seguida no ranking, temos Pão, presente em 32.7% dos carrinhos, e o Chá, presente em 14% dos carrinhos.
#
# > Quando olhamos para itens vendidos em conjunto, temos a combinação (Pão, Café) aparecendo em 9% dos carrinhos, e a combinação (Café, Bolo) aparecendo em 5% dos carrinhos.

# %% [markdown]
# ## **7. Quais combos a padaria pode criar para estimular as vendas?**

# %% [markdown]
# Conhecidos a frequência dos itens mais vendidos, vamos para as regras de associação, e calcular o lift, confiança e convicção.
#
# Aqui, queremos selecionar apenas as regras que tenham lift maior que 1. Ou seja, conjuntos onde exista uma relação de compra entre os itens.

# %%
#Obtendo as medidas de confiança e lift

regras_associacao = association_rules(freq_items, metric = "lift", min_threshold = 1)
regras_associacao.sort_values('confidence', ascending = False, inplace = True)
regras_associacao[['antecedents', 'consequents', 'confidence', 'lift']].reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            antecedents         consequents  confidence  lift
# 0            (Torrada)              (Café)        0.70  1.47
# 1    (Brunch espanhol)              (Café)        0.60  1.25
# 2          (Medialuna)              (Café)        0.57  1.19
# 3      (Massa folhada)              (Café)        0.55  1.15
# 4          (Alfajores)              (Café)        0.54  1.13
# 5               (Suco)              (Café)        0.53  1.12
# 6          (Sanduíche)              (Café)        0.53  1.11
# 7               (Bolo)              (Café)        0.53  1.10
# 8            (Bolinho)              (Café)        0.52  1.09
# 9          (Biscoitos)              (Café)        0.52  1.08
# 10  (Chocolate quente)              (Café)        0.51  1.06
# 11           (Brownie)              (Café)        0.49  1.03
# 12            (Muffin)              (Café)        0.49  1.02
# 13     (Massa folhada)               (Pão)        0.34  1.03
# 14              (Bolo)               (Chá)        0.23  1.60
# 15         (Chá, Café)              (Bolo)        0.20  1.94
# 16         (Sanduíche)               (Chá)        0.20  1.40
# 17  (Chocolate quente)              (Bolo)        0.20  1.88
# 18        (Café, Bolo)               (Chá)        0.18  1.29
# 19               (Chá)              (Bolo)        0.17  1.60
# 20     (Massa folhada)         (Pão, Café)        0.13  1.44
# 21         (Pão, Café)     (Massa folhada)        0.12  1.44
# 22              (Café)              (Bolo)        0.11  1.10
# 23         (Pão, Café)              (Bolo)        0.11  1.07
# 24              (Bolo)  (Chocolate quente)        0.11  1.88
# 25               (Chá)         (Sanduíche)        0.10  1.40
# 26              (Café)     (Massa folhada)        0.10  1.15
# 27              (Bolo)         (Pão, Café)        0.10  1.07
# 28              (Bolo)         (Chá, Café)        0.10  1.94
# 29               (Pão)     (Massa folhada)        0.09  1.03
# 30              (Café)         (Sanduíche)        0.08  1.11
# 31              (Café)         (Medialuna)        0.07  1.19
# 32               (Chá)        (Café, Bolo)        0.07  1.29
# 33              (Café)  (Chocolate quente)        0.06  1.06
# 34              (Café)         (Biscoitos)        0.06  1.08
# 35              (Café)           (Torrada)        0.05  1.47
# 36              (Café)              (Suco)        0.04  1.12
# 37              (Café)           (Brownie)        0.04  1.03
# 38              (Café)         (Alfajores)        0.04  1.13
# 39              (Café)            (Muffin)        0.04  1.02
# 40              (Café)           (Bolinho)        0.04  1.09
# 41              (Café)   (Brunch espanhol)        0.02  1.25

# %%
regras_associacao[['confidence', 'lift']].describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        confidence   lift
# count       42.00  42.00
# mean         0.25   1.26
# std          0.21   0.27
# min          0.02   1.02
# 25%          0.08   1.08
# 50%          0.13   1.13
# 75%          0.50   1.40
# max          0.70   1.94

# %% [markdown]
# **Observações:**
#
# >Temos uma lista com 42 recomendações de combinações de itens.
#
# >Lift: a média de lift é apenas um pouco acima do treshold (1) para a medida.
#
# >Confiança: a média de confiança da nossa lista é de cerca de 25%.

# %% [markdown]
# Café é o item mais vendido na padaria, portanto é natural que a algoritimo recomende o item quando outros são comprados. No entanto, estamos interessados nas associações menos óbvias, portanto desconsideraremos as sugestões em que café aparece como consequente.
#
# Também queremos fazer um recorte em que a confiança seja superior a 10%.

# %%
#Criando novo DF sem Café como possível item em consequente

regra_sem_cafe = regras_associacao[(regras_associacao['consequents'] != {'Café'}) &
                                   (regras_associacao['confidence'] > 0.1)]

#Visualizando o novo DF

regra_sem_cafe[['antecedents', 'consequents', 'confidence', 'lift']].reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            antecedents         consequents  confidence  lift
# 0      (Massa folhada)               (Pão)        0.34  1.03
# 1               (Bolo)               (Chá)        0.23  1.60
# 2          (Chá, Café)              (Bolo)        0.20  1.94
# 3          (Sanduíche)               (Chá)        0.20  1.40
# 4   (Chocolate quente)              (Bolo)        0.20  1.88
# 5         (Café, Bolo)               (Chá)        0.18  1.29
# 6                (Chá)              (Bolo)        0.17  1.60
# 7      (Massa folhada)         (Pão, Café)        0.13  1.44
# 8          (Pão, Café)     (Massa folhada)        0.12  1.44
# 9               (Café)              (Bolo)        0.11  1.10
# 10         (Pão, Café)              (Bolo)        0.11  1.07
# 11              (Bolo)  (Chocolate quente)        0.11  1.88
# 12               (Chá)         (Sanduíche)        0.10  1.40

# %% [markdown]
# **Observações:**
#
# > Chegamos a uma lista final com 13 combos que a padaria pode criar para estimular as vendas.
